# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time

# %%
search_text = input('크롤링할 키워드를 입력하세요')
# Out:
# 크롤링할 키워드를 입력하세요여행

# %%
driver = webdriver.Chrome('./chromedriver')
driver.set_window_size(800,1000)
driver.get('https://korean.visitkorea.or.kr')
time.sleep(2)

# %%
driver.find_element_by_id('chkForm01').click()
element = driver.find_element_by_id('inp_search')
element.send_keys(search_text)
driver.find_element_by_class_name('btn_search2').click()
time.sleep(2)

# %%
page_num = 6
f = open('test.txt', 'a', encoding = 'utf-8')

for i in range(1, page_num +1):
    html_source = driver.page_source
    soup= BeautifulSoup(html_source, 'html.parser')
    
    content_list = soup.select('#contents > div > div.box_leftType1 > ul')
    lis = content_list[0].select('li')
    
    for li in lis:
        print(li.text)
        print()
        f.write(li.text + '\n')
        
    i += 1
    print(i)
    time.sleep(2)
    try:
        driver.find_element_by_link_text("{}".format(i)).click()
    except:
        driver.find_element_by_link_text('다음').click()
    time.sleep(2)
    
    if i > page_num+1:
        f.close()
        driver.quit()
        break
# Out:
#   [8월 걷기여행길9선] 금강 위에 피어나는 노을, 노을 위에 뜬 달, 충북 영동군 양산팔경금강둘레길  충청북도 영동군 #걷기여행길 더보기  즐겨찾기 공유하기
#
# 즐겨찾기
#
# 공유하기
#
#   시간 여행 하는 화산 돌멩이를 찾아서, 한탄강지질공원  경기도  #한탄강지질공원#재인폭포#고대산자연휴양림#당포성#임진강#주상절리#전곡리토층전시관#전곡선사박물관#산정호수#비둘기낭폭포#추천가볼만한곳#경기도가볼만한곳#경기도당일코스#경기도1박2일코스#포천가볼만한곳#연천가볼만한곳#가족여행#4월추천가볼만한곳#2018년4월추천가볼만한곳 더보기  즐겨찾기 공유하기
#
# 즐겨찾기
#
# 공유하기
#
#   [일주일 살아보기 시즌 2] 은퇴 후 첫 여행, 아내와 단둘이 남해로  경상남도 남해군 #일주일살아보기여행#가족과함께#남해여행#남해가볼만한곳#일주일살아보기_시즌2#9월가볼만한곳 더보기  즐겨찾기 공유하기
#
# 즐겨찾기
#
# 공유하기
#
#   감각이 살아나는 정선 화암동굴 여행  강원도 정선군 #생태관광#생태여행코스#2020생태테마사업#2020생태테마관광지#생태테마사업#정선화암동굴#그림바위미술마을#정선향토박물관#천포금광촌 더보기  즐겨찾기 공유하기
#
# 즐겨찾기
#
# 공유하기
#
#   봄이 아니어도 친하게 진해. 감성충만 진해여행 코스  경상남도 창원시 #진해여행코스#소사동마을#진해가볼만한곳#창원여행#진해여행#진해해양공원#진해보타닉뮤지엄#원해루#제황산#제황산모노레일#진해탑#안민고개#초여름_더욱_빛나는 더보기  즐겨찾기 공유하기
#
# 즐겨찾기
#
# 공유하기
#
#   한국관광공사 추천 5월 걷기여행길, 유네스코 세계문화유산 산사 걷기길  전국 #걷기여행길#5월걷기여행길#트레킹코스#관광공사추천_5월걷기여행길#5월_걷기여행길 더보기  즐겨찾기 공유하기
#
# 즐겨찾기
#
# 공유하기
#
#   [지역명사와 함께하는 문화여행] 고판화에 미친 사람, 한선학 명사  강원도 원주시 #지역명사와_함께하는_문화여행#원주#한선학명사 더보기  즐겨찾기 공유하기
#
# 즐겨찾기
#
# 공유하기
#
#   [인천] 뚜벅이 알뜰여행의 베이스캠프, 인천 '호텔 아띠'  인천 중구 #한국관광품질인증#여행Q레이터#여행Q레이터체험기#추천숙박#체험기#호텔아띠#여행자의방 더보기  즐겨찾기 공유하기
#
# 즐겨찾기
#
# 공유하기
#
#   전어·꽃게·대하 가을 별미 삼총사와 함께한 서해안 가을 여행  충청남도 서천군 #공공누리#가을축제/행사#가을제철먹거리#가을제철음식#가을가볼만한곳#서해안가볼만한곳#먹방여행#구석구석미식회 더보기  즐겨찾기 공유하기
#
# 즐겨찾기
#
# 공유하기
#
#   가족여행으로 딱! 문경 겨울 여행  경상북도 문경시 #문경여행#문경가볼만한곳#가족여행#세구기매운탕#가나다라브루어리#고모산성#에코랄라 더보기  즐겨찾기 공유하기
#
# 즐겨찾기
#
# 공유하기
#
더보기  즐겨찾기 공유하기
#
# 즐겨찾기
#
# 공유하기
#
#   원주 출렁다리&여행코스. 출렁다리만 갈거야? 원주 가볼만한곳 BEST 6  강원도 원주시 #원주여행코스#원주가볼만한곳#원주소금산#원주소금산출렁다리#원주출렁다리#원주1박2일여행코스#원주게스트하우스#원주맛집#원주여행지추천#원주데이트코스#19_20한국관광100선#한국관광100선#강원권#강원#원주소금산출렁다리 더보기  즐겨찾기 공유하기
#
# 즐겨찾기
#
# 공유하기
#
#   청주로 실속여행 '가즈아~'  충청북도 청주시 #무장애여행지#열린관광_모두의여행#장애인추천코스#충북청주#공공누리#장애인추천여행지#모두의관광, 열린여행지 더보기  즐겨찾기 공유하기
#
# 즐겨찾기
#
# 공유하기
#
#   [여행 카드] 떠나세요, 당신의 가을은 찰나입니다.  경기도 여주시 #서울가볼만한곳#남양주가볼만한곳#여주가볼만한곳#청주가볼만한곳#단풍여행#캠핑#전시관#자전거여행#청주축제#올림픽공원#나홀로나무#억새숲#강천섬#은행나무길#느티나무숲#국화축제#능내역#힐링#캠핑코스 더보기  즐겨찾기 공유하기
#
# 즐겨찾기
#
# 공유하기
#
#   핫플레이스부터 문화예술 투어까지! 광주지하철 여행  광주 #광주#광주지하철#펭귄마을#1913송정역시장#광주극장#국립아시아문화전당#양림동역사문화마을#오웬기념관#한희원미술관#이강하미술관#518자유공원미술관#김대중컨벤션센터#여행#지하철여행#추천가볼만한곳#광주가볼만한곳#광주당일코스#광주1박2일코스#추천가볼만한곳#2018년3월추천가볼만한곳#겨울기차여행#2월가볼만한곳#뉴트로_감성여행#여자혼자_여행하기_좋은곳#프사_백만장_인생샷 더보기  즐겨찾기 공유하기
#
# 즐겨찾기
#
# 공유하기
#
#   [지역명사와 함께하는 여행 특집테마] 고품격 지역명사와 함께하는 문화여행  전국 #지역명사#지역명사와_함께하는_문화여행#테마여행 더보기  즐겨찾기 공유하기
#
# 즐겨찾기
#
# 공유하기
#
#   에티오피아가 가까워지는 춘천 여행, 에티오피아한국전참전기념관  강원도 춘천시 #2019년4월추천가볼만한곳#4월추천가볼만한곳#추천가볼만한곳#이색적인여행#공공누리#4월가볼만한곳#이런여행은어때요?#강원도여행 더보기  즐겨찾기 공유하기
#
# 즐겨찾기
#
# 공유하기
#
#   60대 인싸들의 흥 폭발 포천여행  경기도 포천시 #열린관광_모두의여행#어르신추천코스#어르신#무장애여행추천코스#경기도#포천 더보기  즐겨찾기 공유하기
#
# 즐겨찾기
#
# 공유하기
#
#   오지게 멋진 제주 건축물 여행  제주도  #제주여행코스#제주가볼만한곳#제주건축물여행#국내건축물#제주건축여행#안도타다오#이타미준#제주가을여행코스#제주가을여행지추천#제주여행지추천 더보기  즐겨찾기 공유하기
#
# 즐겨찾기
#
# 공유하기
#
# 7

# %%
def visitkor_search():
    
    search_text = input('크롤링할 키워드를 입력하세요..')
    
    driver = webdriver.Chrome()
    driver.set_window_size(800,1000)
    driver.get('https://korean.visitkorea.or.kr')
    time.sleep(3)
    
    driver.find_element_by_id('chkForm01').click()
    elem = driver.find_element_by_class_name('inp_search')
    elem.send_keys(search_text)
    driver.find_element_by_class_name('btn_search2').click()
    time.sleep(3)
    
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    content_list = soup.select('#contents > div > div.box_leftType1 > ul')
    lis = content_list[0].select('li')
    
    for i in range(0, len(lis), 3):
        print('=============')
        print('제목:',lis[i].select('div.tit > a')[0].text)
        print('지역:',lis[i].select('div.area_txt > p')[0].text)   
        print('태그:',lis[i].select('p.tag > span')[0].text)  
        
    title_list = []
    area_list = []
    tag_list = []
    
    for i in range(0, len(lis), 3):
        title_list.append(lis[i].select('div.tit > a')[0].text)
        area_list.append(lis[i].select('div.area_txt > p')[0].text)   
        tag_list.append(lis[i].select('p.tag > span')[0].text) 

    return title_list, area_list, tag_list, driver

# %%
visitkor_search()
# Out:
# 크롤링할 키워드를 입력하세요..여행
# =============
# 제목: [8월 걷기여행길9선] 금강 위에 피어나는 노을, 노을 위에 뜬 달, 충북 영동군 양산팔경금강둘레길
# 지역: 충청북도 영동군
# 태그: #걷기여행길
# =============
# 제목: 시간 여행 하는 화산 돌멩이를 찾아서, 한탄강지질공원
# 지역: 경기도
# 태그: #한탄강지질공원
# =============
# 제목: [일주일 살아보기 시즌 2] 은퇴 후 첫 여행, 아내와 단둘이 남해로
# 지역: 경상남도 남해군
# 태그: #일주일살아보기여행
# =============
# 제목: 감각이 살아나는 정선 화암동굴 여행
# 지역: 강원도 정선군
# 태그: #생태관광
# =============
# 제목: 봄이 아니어도 친하게 진해. 감성충만 진해여행 코스
# 지역: 경상남도 창원시
# 태그: #진해여행코스
# =============
# 제목: 한국관광공사 추천 5월 걷기여행길, 유네스코 세계문화유산 산사 걷기길
# 지역: 전국
# 태그: #걷기여행길
# =============
# 제목: [지역명사와 함께하는 문화여행] 고판화에 미친 사람, 한선학 명사
# 지역: 강원도 원주시
# 태그: #지역명사와_함께하는_문화여행
# =============
# 제목: [인천] 뚜벅이 알뜰여행의 베이스캠프, 인천 '호텔 아띠'
# 지역: 인천 중구
# 태그: #한국관광품질인증
# =============
# 제목: 전어·꽃게·대하 가을 별미 삼총사와 함께한 서해안 가을 여행
# 지역: 충청남도 서천군
# 태그: #공공누리
# =============
# 제목: 가족여행으로 딱! 문경 겨울 여행
# 지역: 경상북도 문경시
# 태그: #문경여행
# (['[8월 걷기여행길9선] 금강 위에 피어나는 노을, 노을 위에 뜬 달, 충북 영동군 양산팔경금강둘레길',
#   '시간 여행 하는 화산 돌멩이를 찾아서, 한탄강지질공원',
#   '[일주일 살아보기 시즌 2] 은퇴 후 첫 여행, 아내와 단둘이 남해로',
#   '감각이 살아나는 정선 화암동굴 여행',
#   '봄이 아니어도 친하게 진해. 감성충만 진해여행 코스',
#   '한국관광공사 추천 5월 걷기여행길, 유네스코 세계문화유산 산사 걷기길',
#   '[지역명사와 함께하는 문화여행] 고판화에 미친 사람, 한선학 명사',
#   "[인천] 뚜벅이 알뜰여행의 베이스캠프, 인천 '호텔 아띠'",
#   '전어·꽃게·대하 가을 별미 삼총사와 함께한 서해안 가을 여행',
#   '가족여행으로 딱! 문경 겨울 여행'],
#  ['충청북도 영동군',
#   '경기도 ',
#   '경상남도 남해군',
#   '강원도 정선군',
#   '경상남도 창원시',
#   '전국',
#   '강원도 원주시',
#   '인천 중구',
#   '충청남도 서천군',
#   '경상북도 문경시'],
#  ['#걷기여행길',
#   '#한탄강지질공원',
#   '#일주일살아보기여행',
#   '#생태관광',
#   '#진해여행코스',
#   '#걷기여행길',
#   '#지역명사와_함께하는_문화여행',
#   '#한국관광품질인증',
#   '#공공누리',
#   '#문경여행'],
#  <selenium.webdriver.chrome.webdriver.WebDriver (session="bf3ea39c391c10f0db5bfd6890eea8b5")>)

# %%
page_num = int(input('몇 페이지까지 크롤링할지 페이지 넘버를 입력하세요.'))

title_lists = []
area_lists = []
tag_lists = []

for i in range(2, page_num+1):
    
    title_list, area_list, tag_list, driver = visitkor_search()
    
    title_lists.append(title_list)
    area_lists.append(area_list)
    tag_lists.append(tag_list)
    
    driver.find_element_by_id("{}".format(i)).click()
